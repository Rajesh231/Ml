# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajesh231/Ml/blob/master/BotnetDetection_CNN_HighAccNdLowLoss_withAccAsOptimizationMetric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Botnet Detection using CTU-13 dataset

# %%
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.3)

# %%
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.callbacks import EarlyStopping 
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from tensorflow.keras.layers import Conv1D, MaxPool1D,Flatten,Dense,Dropout,BatchNormalization 
print(tf.__version__)
# Out:
# 2.2.0-rc4

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from sklearn.feature_selection import variance_threshold
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.variance_threshold module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# **Reading the CSV file from Mounted Google Drive**

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/finalpreprocessed2.csv") 
df.head()
# Out:
#            Dur  Proto  Sport  Dport State  TotPkts  TotBytes  SrcBytes  Label
# 0     0.055572      1  13485      1   CON        2       128        60      0
# 1     0.097566      1  35155     10   CON        2       474       145      0
# 2     0.000000      1  35155     21   INT        1       145       145      0
# 3  3598.238525      1  43565     23   CON      876     96819     47731      0
# 4  3591.619629      1  43565     23   CON      867     95866     47068      0

# %%
df.shape
# Out:
# (1038261, 9)

# %% [markdown]
# **Preprocessing of the data which left after preprocessing in MS Excel**

# %%
X = df.drop(labels =['Label','State'],axis =1) 
X.shape
# Out:
# (1038261, 7)

# %%
y = df['Label']

# %%
#stratified shuffling is done to divide the data in equal ration on the basis of parameter label
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 0, stratify =y)

# %%
X_train.shape
# Out:
# (830608, 7)

# %%
X_test.shape
# Out:
# (207653, 7)

# %%
from sklearn.feature_selection import VarianceThreshold 
filter = VarianceThreshold(0.01) 
X_train = filter.fit_transform(X_train) 
X_test = filter.transform(X_test) 
X_train.shape, X_test.shape
# Out:
# ((830608, 7), (207653, 7))

# %%
#X_train_T = X_train.T
#X_test_T = X_test.T

# %%
#X_train_T = pd.DataFrame(X_train_T)
#X_test_T = pd.DataFrame(X_test_T)
#X_test_T.shape

# %%
#X_train_T.duplicated().sum()

# %%
#duplicated_features = X_train_T.duplicated()
#duplicated_features

# %%
#features_to_keep = [not index for index in duplicated_features]
#features_to_keep

# %%
#X_train = X_train_T[features_to_keep].T
#X_train.shape

# %%
#X_test = X_test_T[features_to_keep].T
#X_test.shape

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[ 1.32183022e+00, -4.10682002e-01,  1.21757026e-01, ...,
#         -5.94007613e-03, -5.25711261e-03, -2.22797778e-03],
#        [-4.36049922e-01,  1.76424631e+00,  1.05061137e+00, ...,
#         -4.67969135e-03, -5.04774498e-03, -2.01168354e-03],
#        [ 1.36370248e+00, -4.10682002e-01, -6.23215051e-01, ...,
#         -5.51994787e-03, -5.25931648e-03, -2.20572529e-03],
#        ...,
#        [-4.50335745e-01,  1.76424631e+00, -1.70264449e+00, ...,
#          5.82351518e-03,  5.68490042e-03, -1.88113557e-03],
#        [-4.50444677e-01, -4.10682002e-01, -1.78609203e+00, ...,
#         -6.36020439e-03, -5.30479633e-03, -2.25260388e-03],
#        [ 1.90868320e+00, -4.10682002e-01,  1.27503703e+00, ...,
#         -5.09981961e-03, -5.14892264e-03, -2.06241923e-03]])

# %%
X_test
# Out:
# array([[-0.45049884, -0.410682  ,  0.77599401, ..., -0.0063602 ,
#         -0.00524549, -0.00225409],
#        [-0.45049905, -0.410682  ,  1.01827929, ..., -0.0063602 ,
#         -0.00530119, -0.0022526 ],
#        [-0.45049862, -0.410682  ,  1.3358008 , ..., -0.0063602 ,
#         -0.00526272, -0.0022526 ],
#        ...,
#        [ 0.89467327, -0.410682  , -0.57774486, ..., -0.00594008,
#         -0.00528817, -0.00223065],
#        [-0.45049838, -0.410682  ,  1.1983125 , ..., -0.0063602 ,
#         -0.00531501, -0.0022526 ],
#        [ 0.35424977, -0.410682  , -0.08850411, ..., -0.0063602 ,
#         -0.00528476, -0.00219   ]])

# %%
X_train.shape,X_test.shape
# Out:
# ((830608, 7), (207653, 7))

# %%
X_train = X_train.reshape(830608,7,1) 
X_test = X_test.reshape(207653,7,1)

# %%
X_test.shape,X_train.shape
# Out:
# ((207653, 7, 1), (830608, 7, 1))

# %%
#as y is a series so y_train and y_test are also series therefore we need to convert them to a numpy array.
y_train = y_train.to_numpy() 
y_test = y_test.to_numpy()

# %% [markdown]
# **Model buildin process starts from here. I will build this model using Convolutional Neural Networks**

# %%
from tensorflow.keras.layers import MaxPool1D
from keras.models import load_model
model = Sequential()
model.add(Conv1D(64,3,activation='relu',input_shape=(7,1)))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size =2))
model.add(Dropout(0.1))

model = Sequential()
model.add(Conv1D(128,3,activation='relu',input_shape=(7,1)))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.5))

model = Sequential()
model.add(Conv1D(128,3,activation='relu',input_shape=(7,1)))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.2))

model = Sequential()
model.add(Conv1D(256,3,activation='relu',input_shape=(7,1)))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation = 'sigmoid'))
#model.add(EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='min', baseline=None, restore_best_weights=True))
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 5, 256)            1024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 256)            1024
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 2, 256)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 133,633
# Trainable params: 133,121
# Non-trainable params: 512
# _________________________________________________________________

# %%
# compile the model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
#model.compile(optimizer=SGD(lr=0.000005),loss ="binary_crossentropy",metrics = ['f1_score'])
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy']) 

#simple early stopping and model chekcpoint functions
es = EarlyStopping(monitor='accuracy',mode = 'max',verbose =1,patience = 13)
mc = ModelCheckpoint("/content/drive/My Drive/Colab Notebooks/best_model1.h5",monitor = 'accuracy', mode = 'max', verbose =1, save_best_only = True)
lr = ReduceLROnPlateau(monitor = "accuracy", factor = 0.1, patience = 6, verbose = 0, mode = "max", min_delta= 1e-03, cooldown = 0,min_lr = 0)
# fit the model
#history = model.fit(Xtrain, ytrain, validation_split=0.3, epochs=10, verbose=0)

# evaluate the model
#loss, accuracy, f1_score, precision, recall = model.evaluate(Xtest, ytest, verbose=0)

# %%
history = model.fit(X_train,y_train,epochs = 225,validation_split=0.25 ,verbose =1,callbacks=[es,mc,lr])
# Out:
# Epoch 1/225
# 19465/19468 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9913
# Epoch 00001: accuracy improved from -inf to 0.99127, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0306 - accuracy: 0.9913 - val_loss: 0.0256 - val_accuracy: 0.9918 - lr: 0.0010
# Epoch 2/225
# 19468/19468 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9919
# Epoch 00002: accuracy improved from 0.99127 to 0.99187, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 109s 6ms/step - loss: 0.0275 - accuracy: 0.9919 - val_loss: 0.0251 - val_accuracy: 0.9919 - lr: 0.0010
# Epoch 3/225
# 19466/19468 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9919
# Epoch 00003: accuracy improved from 0.99187 to 0.99189, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 107s 5ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 0.0265 - val_accuracy: 0.9919 - lr: 0.0010
# Epoch 4/225
# 19468/19468 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9919
# Epoch 00004: accuracy did not improve from 0.99189
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 0.0262 - val_accuracy: 0.9918 - lr: 0.0010
# Epoch 5/225
# 19468/19468 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9918
# Epoch 00005: accuracy did not improve from 0.99189
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0268 - accuracy: 0.9918 - val_loss: 0.0259 - val_accuracy: 0.9918 - lr: 0.0010
# Epoch 6/225
# 19467/19468 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9920
# Epoch 00006: accuracy improved from 0.99189 to 0.99196, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 107s 5ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.0297 - val_accuracy: 0.9927 - lr: 0.0010
# Epoch 7/225
# 19461/19468 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9920
# Epoch 00007: accuracy improved from 0.99196 to 0.99198, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 107s 5ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.0230 - val_accuracy: 0.9930 - lr: 0.0010
# Epoch 8/225
# 19462/19468 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9931
# Epoch 00008: accuracy improved from 0.99198 to 0.99314, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.0205 - val_accuracy: 0.9932 - lr: 1.0000e-04
# Epoch 9/225
# 19468/19468 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9935
# Epoch 00009: accuracy improved from 0.99314 to 0.99345, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.0191 - val_accuracy: 0.9935 - lr: 1.0000e-04
# Epoch 10/225
# 19467/19468 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9939
# Epoch 00010: accuracy improved from 0.99345 to 0.99388, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.0184 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 11/225
# 19467/19468 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9940
# Epoch 00011: accuracy improved from 0.99388 to 0.99401, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0187 - accuracy: 0.9940 - val_loss: 0.0181 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 12/225
# 19460/19468 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9941
# Epoch 00012: accuracy improved from 0.99401 to 0.99405, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0179 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 13/225
# 19462/19468 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9942
# Epoch 00013: accuracy improved from 0.99405 to 0.99415, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 107s 5ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0181 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 14/225
# 19467/19468 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9942
# Epoch 00014: accuracy improved from 0.99415 to 0.99416, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0179 - val_accuracy: 0.9943 - lr: 1.0000e-04
# Epoch 15/225
# 19467/19468 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9942
# Epoch 00015: accuracy improved from 0.99416 to 0.99417, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 106s 5ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.0177 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 16/225
# 19459/19468 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9942
# Epoch 00016: accuracy improved from 0.99417 to 0.99421, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 107s 5ms/step - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0176 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 17/225
# 19464/19468 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9942
# Epoch 00017: accuracy did not improve from 0.99421
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0184 - val_accuracy: 0.9943 - lr: 1.0000e-04
# Epoch 18/225
# 19464/19468 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9942
# Epoch 00018: accuracy did not improve from 0.99421
# 19468/19468 [==============================] - 104s 5ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0178 - val_accuracy: 0.9941 - lr: 1.0000e-04
# Epoch 19/225
# 19463/19468 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9942
# Epoch 00019: accuracy improved from 0.99421 to 0.99423, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 108s 6ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0174 - val_accuracy: 0.9942 - lr: 1.0000e-04
# Epoch 20/225
# 19466/19468 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9943
# Epoch 00020: accuracy improved from 0.99423 to 0.99429, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0171 - val_accuracy: 0.9942 - lr: 1.0000e-05
# Epoch 21/225
# 19458/19468 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9943
# Epoch 00021: accuracy improved from 0.99429 to 0.99431, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0171 - val_accuracy: 0.9942 - lr: 1.0000e-05
# Epoch 22/225
# 19462/19468 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9943
# Epoch 00022: accuracy improved from 0.99431 to 0.99434, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 108s 6ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0172 - val_accuracy: 0.9942 - lr: 1.0000e-05
# Epoch 23/225
# 19468/19468 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9944
# Epoch 00023: accuracy improved from 0.99434 to 0.99437, saving model to /content/drive/My Drive/Colab Notebooks/best_model1.h5
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0170 - val_accuracy: 0.9942 - lr: 1.0000e-05
# Epoch 24/225
# 19459/19468 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9943
# Epoch 00024: accuracy did not improve from 0.99437
# 19468/19468 [==============================] - 104s 5ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.0192 - val_accuracy: 0.9941 - lr: 1.0000e-05
# Epoch 25/225
# 19464/19468 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9943
# Epoch 00025: accuracy did not improve from 0.99437
# 19468/19468 [==============================] - 104s 5ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0171 - val_accuracy: 0.9942 - lr: 1.0000e-05
# Epoch 26/225
# Epoch 36/225
# 19461/19468 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9944
# Epoch 00036: accuracy did not improve from 0.99438
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0169 - val_accuracy: 0.9943 - lr: 1.0000e-07
# Epoch 37/225
# 19459/19468 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9943
# Epoch 00037: accuracy did not improve from 0.99438
# 19468/19468 [==============================] - 104s 5ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0169 - val_accuracy: 0.9942 - lr: 1.0000e-07
# Epoch 38/225
# 19466/19468 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9944
# Epoch 00038: accuracy did not improve from 0.99438
# 19468/19468 [==============================] - 104s 5ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0170 - val_accuracy: 0.9942 - lr: 1.0000e-08
# Epoch 39/225
# 19463/19468 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9943
# Epoch 00039: accuracy did not improve from 0.99438
# 19468/19468 [==============================] - 105s 5ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.0170 - val_accuracy: 0.9942 - lr: 1.0000e-08
# Epoch 40/225
# 19461/19468 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9944
# Epoch 00040: accuracy did not improve from 0.99438
# 19468/19468 [==============================] - 103s 5ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.0169 - val_accuracy: 0.9942 - lr: 1.0000e-08
# Epoch 00040: early stopping

# %%
# Recreate the exact same model, including its weights and the optimizer by loading our saved model.
model = tf.keras.models.load_model("/content/drive/My Drive/Colab Notebooks/best_model1.h5")

# Show the model architecture
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 5, 256)            1024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 256)            1024
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 2, 256)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 133,633
# Trainable params: 133,121
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# **Evaluating the loaded or saved model to have a glance over training accuracy, training loss and testing accuracy, testing loss**

# %%
#evaluating the model 
trainloss,trainacc = model.evaluate(X_train,y_train,verbose=0)
testloss,testacc = model.evaluate(X_test,y_test,verbose=0)
print('train: trainacc= %.3f,trainloss= %.3f, Test: testacc= % .3f, testloss= %.3f'%(trainacc,trainloss,testacc,testloss))
# Out:
# train: trainacc= 0.994,trainloss= 0.017, Test: testacc=  0.994, testloss= 0.017

# %%
 y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([[4.6352895e-12],
#        [2.3064558e-12],
#        [8.5722601e-14],
#        ...,
#        [9.5334270e-12],
#        [6.3192044e-23],
#        [2.2548173e-14]], dtype=float32)

# %%
history.history
# Out:
# {'accuracy': [0.9912738800048828,
#   0.9918709993362427,
#   0.9918902516365051,
#   0.9918661713600159,
#   0.9917827248573303,
#   0.9919561147689819,
#   0.9919785857200623,
#   0.993135929107666,
#   0.9934505820274353,
#   0.9938808083534241,
#   0.9940075874328613,
#   0.994052529335022,
#   0.9941536784172058,
#   0.9941552877426147,
#   0.9941729307174683,
#   0.994245171546936,
#   0.9942548274993896,
#   0.9942403435707092,
#   0.9942499995231628,
#   0.9942499995231628,
#   0.9942499995231628],
#  'val_loss': [0.02560580149292946,
#   0.025093186646699905,
#   0.02651955932378769,
#   0.02622148208320141,
#   0.025936152786016464,
#   0.029733140021562576,
#   0.022982602939009666,
#   0.02048775553703308,
#   0.01914302073419094,
#   0.018385088071227074,
#   0.018098751083016396,
#   0.01788288541138172,
#   0.01806759089231491,
#   0.017922984436154366,
#   0.017749540507793427,
#   0.017589595168828964,
#   0.018359117209911346,
#   0.01782151311635971,
#   0.017446598038077354,
#   0.017100973054766655,
#   0.017101136967539787,
#   0.017150864005088806,
#   0.017037099227309227,
#   0.019154461100697517,
#   0.01711994595825672,
#   0.017021426931023598,
#   0.016985896974802017,
#   0.017024340108036995,
#   0.01699666865170002,
#   0.01698850281536579,
#   0.01695900969207287,
#   0.016981028020381927,
#   0.0169630479067564,
#   0.016966471448540688,
#   0.01695704087615013,
#   0.016942651942372322,
#   0.016937393695116043,
#   0.016959339380264282,
#   0.01695478893816471,
#   0.01694461889564991]}

# %%
print(history.history['accuracy'])
# Out:
# [0.9912738800048828, 0.9918709993362427, 0.9918902516365051, 0.9918661713600159, 0.9917827248573303, 0.9919561147689819, 0.9919785857200623, 0.993135929107666, 0.9934505820274353, 0.9938808083534241, 0.9940075874328613, 0.994052529335022, 0.9941536784172058, 0.9941552877426147, 0.9941729307174683, 0.994214653968811, 0.9942082762718201, 0.9941825866699219, 0.9942259192466736, 0.9942933320999146, 0.994306206703186, 0.9943366646766663, 0.9943655729293823, 0.9943382740020752, 0.9943254590034485, 0.9943607449531555, 0.9943752288818359, 0.9943463206291199, 0.9943479299545288, 0.9943350553512573, 0.9943687915802002, 0.9943559169769287, 0.9943527579307556, 0.9943350553512573, 0.9943479299545288, 0.9943527579307556, 0.994306206703186, 0.9943559169769287, 0.9943414926528931, 0.9943720102310181]

# %%
def plot_learningCurve(history,epoch):
  #ploting training & validation accuracy values
  epoch_range = range(1,epoch+1)
  plt.plot(epoch_range,history.history['accuracy'])
  plt.plot(epoch_range,history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train','test'],loc='right')
  plt.show()

#plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range,history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('loss')
  plt.xlabel('Epoch')
  plt.legend(['Train','test'],loc='right')
  plt.show()

# %%
plot_learningCurve(history,40)

# %% [markdown]
# **By looking at the above learning curves we can say that our model is neither underfitting nor overfitting as the curves for both training and testing data are nearly same. If model was underfitting then these two curves would have huge variation and if model was overfitting then these two curves may be moving in opposite direction**

# %%
y_predict = np.asarray(y_predict)

# %%
from sklearn.metrics import confusion_matrix
conff = confusion_matrix(y_test,y_predict.round())
conff
# Out:
# array([[202161,    100],
#        [  1069,   4323]])

# %%
#Plotting Confusion matrix
import itertools
import matplotlib.pyplot as plt
classes = [0,1]
plt.imshow(conff,interpolation='nearest',cmap=plt.cm.Greens)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks,classes)
plt.yticks(tick_marks,classes)
accuracy = max(history.history['accuracy'])
misclass =1-max(history.history['accuracy'])
fmt ='d'
thresh = conff.max()/2
for i, j in itertools.product(range(conff.shape[0]),range(conff.shape[1])):
  plt.text(j,i,format(conff[i,j],fmt),horizontalalignment='center', color="white" if conff[i,j]>thresh else "black")
  plt.tight_layout()
  plt.ylabel('True label')
  #plt.xlabel('Predicted label')
  plt.xlabel('Predicted label ( 1-True,0-False )\naccuracy={:0.3f}; misclass={:0.3f}'.format(accuracy, misclass))

# %%
TP = true_positives = 4323
TN = true_negatives = 202161
FP = false_positives = 1069
FN = false_negatives = 100

# %%
results={}
metric = "Accuracy"
results[metric]=(TP+TN)/(TP+TN+FP+FN)
print(f"{metric} is {results[metric]: .4f}")
# Out:
# Accuracy is  0.9944

# %%
metric = "Precision"
results[metric]=TP/(TP+FN)
print(f"{metric} is {results[metric]: .4f}")
# Out:
# Precision is  0.9774

# %%
metric = "Recall"
results[metric]=TP/(TP+FP)
print(f"{metric} is {results[metric]: .4f}")
# Out:
# Recall is  0.8017

# %%
metric = "F1-Score"
results[metric]= 2/(1/results["Precision"]+1/results["Recall"])
print(f"{metric} is {results[metric]: .4f}")
# Out:
# F1-Score is  0.8809

# %%
#Let's check various metrics using sklearns inbuitl function to compare the values our custom functions generated
from sklearn import metrics
print(f"Actual accuracy_score : {metrics.accuracy_score(y_test,y_predict.round()): .3f}")
print(f"Actual recall_score : {metrics.recall_score(y_test,y_predict.round()): .3f}")
print(f"Actual precision_score : {metrics.precision_score(y_test,y_predict.round()): .3f}")
print(f"Actual f1_score : {metrics.f1_score(y_test,y_predict.round()): .3f}")
# Out:
# Actual accuracy_score :  0.994
# Actual recall_score :  0.802
# Actual precision_score :  0.977
# Actual f1_score :  0.881

# %% [markdown]
# **End of Model Evaluation Process**

# %% [markdown]
#                                                         END of Model Evaluation

# %% [markdown]
# #Let's check the feasibility and accuracy of our model in Production Environment. Here production environment I mean testing the model on new dataset.

# %%
#Let's check the feasibility and accuracy of our model in Production Environment. Here production environment I mean testing the model on new dataset.

dfl = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Book1111.csv")
dfl.head()
# Out:
#         Dur  Proto  Sport  Dport  TotPkts  TotBytes  SrcBytes  Label
# 0  0.000000      5      8      2        1        60        60      0
# 1  0.000000      5      8      2        1        60        60      0
# 2  0.000000      5      8      2        1        98        98      0
# 3  0.000000      5      8      2        1        74        74      0
# 4  0.004731      5      8      2        2       148        74      0

# %%
X1 = dfl.drop('Label',axis=1)
print(X1.shape)
y1=dfl['Label']
print(y1.shape)
# Out:
# (717851, 7)
# (717851,)

# %%
X1=X1.to_numpy()

# %%
X1 = X1.reshape((717851,7,1))
y1 = y1.to_numpy()

print(X1.shape)
print(y1.shape)
# Out:
# (717851, 7, 1)
# (717851,)

# %%
X1.dtype
# Out:
# dtype('float64')

# %%
X1 = np.asarray(X1)
print(X1.dtype)
#X1 = np.expand_dims(X1, -1)
X1.shape
y_predict12 = model.predict(X1)
# Out:
# float64

# %%
y_predict12
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
y_predict12 = np.asarray(y_predict12)

# %%
#Checking the Accuracy achived on real time data
from sklearn import metrics
print(f"Actual accuracy_score : {metrics.accuracy_score(y1,y_predict12.round()): .4f}")
# Out:
# Actual accuracy_score :  0.9842
